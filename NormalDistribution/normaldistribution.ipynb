# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
random=np.random.normal(50,10,1000)
std=10
mean=50
plt.hist(random)
plt.xlabel("value")
plt.ylabel("freq")
plt.axvline(std+mean)
plt.axvline(mean-std)
plt.show()
count=0

# %%
import numpy as np
import matplotlib.pyplot as plt

sample_size = 30
num_samples = 10000

means = []

for _ in range(num_samples):
    sample = np.random.uniform(0,1,sample_size)
    means.append(np.mean(sample))

plt.hist(means, bins=50)
plt.show()

# %%
# CLT stimulation
data=np.random.exponential(10,10000000)
mean_samples=[]
for i in range(1,1000):
    sample=np.random.choice(data,30)
    sample_mean=np.mean(sample)
    mean_samples.append(sample_mean)
plt.hist(data)  
plt.show()
